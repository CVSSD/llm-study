# %%
import llmstudy
from d2l import torch as d2l

data = llmstudy.SyntheticRegressionData(w=d2l.tensor([2, -3.4]), b=4.2)
print('features:', data.X[0],'\nlabel:', data.y[0])
# Out:
# features: tensor([-0.1947, -0.3816])
# label: tensor([5.1166])

# %%
@add_to_class(llmstudy.SyntheticRegressionData)
def print_test(self):
    pass

data.print_test()

@remove_from_class(llmstudy.SyntheticRegressionData)
def print_test(self):
    pass

try:
    data.print_test()
except:
    pass
# Out:
# Method print_test added to class  SyntheticRegressionData
# Method removed.
