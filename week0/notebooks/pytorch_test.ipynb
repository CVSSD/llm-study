# %%
import torch

x = torch.tensor([1,2,3])
print(x)

if torch.cuda.is_available():
    x = x.cuda()
    print(x.device)
# Out:
# tensor([1, 2, 3])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 x = torch.tensor([1,2,3])
#       4 print(x)
#       5
# ----> 6 if torch.cuda.is_availbale():
#       7     x = x.cuda()
#       8     print(x.device)
#
# AttributeError: module 'torch.cuda' has no attribute 'is_availbale'
